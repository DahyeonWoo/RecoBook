# %% [markdown]
# ## 작가 기반 추천시스템 recommendation_by_author
#  - authordata.csv에 있는 author, info(작가설명)을 활용하여 작가를 입력하면 그 작가과 설명이 유사한 작가를 추천
#  - 작동 설명
#      1. info에 있는 데이터들로 임베딩 모델을 만든 뒤 작가마다 특정 벡터값을 가질 수 있도록 토큰화된 단어들의 벡터값의 평균을 낸다.
#      2. 작가를 인자로 입력받으면 해당 작가와 문서 벡터값이 가장 유사한 5명의 작가를 추천한다.

# %% [markdown]
# 1. 데이터 로드

# %%
# 패키지 임포트
# !pip install numpy==1.20.0
# !pip install gensim==3.7.0 --user
import urllib.request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import re
from konlpy.tag import Okt
from io import BytesIO
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity

# %%
# 데이터를 데이터프레임으로 로드하고, 전체 문서의 수 출력

# %%
import io

df = pd.read_csv('authordata.csv')
print('전체 문서의 수 : ', len(df))
# Out:
# 전체 문서의 수 :  417

# %%
# 상위 5행만 출력하여 확인

# %%
df[:5]
# Out:
#    Unnamed: 0 author                                               info  \
# 0           0    나예리  특유의 냉소적인 캐릭터와 독특한 그림체로 데뷔 초기부터 나예리 매니아 집단을 형성한...
# 1           1    이문열  년 서울에서 태어나 경북 영양 밀양 부산 등지에서 자랐다 서울대학교 사범대학에서 수...
# 2           2  조애너 콜  저자 조애너 콜 은 어렸을 때부터 과학을 좋아하는 영리한 소녀였다 신기한 스쿨 버스...
# 3           3    이호백  년 서울 출생 서울대학교 산업 미술학과와 고려대 신문방송학과 대학원을 졸업한 후 파...
# 4           4    권정생  일본 도쿄에서 태어나 광복 직후 우리나라로 돌아왔다 경북 안동 일직면에서 마을 교회...
#
#                                             booklist
# 0  탐정이 될래요/네멋대로 해라!/아마도 달콤하겠지-MAY BE SO SWEET/특명!...
# 1  사람의 아들/사람의 아들/황제를 위하여/금시조/선택/선택/젊은날의 초상/영웅시대/시...
# 2                                    바퀴벌레/강아지가 태어났어요
# 3                세상에서 제일 힘 센 수탉/도대체 그동안 무슨 일이 일어났을까?
# 4  몽실 언니/사과나무 밭 달님/바닷가 아이들/점득이네/하느님의 눈물/밥데기 죽데기/또...

# %%
# 형태소 분석 하기 전 사용자 사전 추가
from ckonlpy.tag import Twitter

twitter = Twitter()
twitter.add_dictionary(list(df['author']), 'Noun')
# Out:
# C:\Users\user\AppData\Roaming\Python\Python38\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
# 'Desc' 열을 대상으로 전처리를 수행하여 'cleaned'에 저장

# %%
def _removeNonAscii(text):
    letters_only = re.sub('[^ 0-9가-힣]', '', text)   
    return letters_only

def remove_stop_words(text):    
    
    twitter = Twitter()
    tokenized_data = []
    #temp_X = twitter.nouns(text) # 토큰화
    temp_X = twitter.morphs(text, stem=True) # 토큰화
    
    # 5. Stopwords 불용어 제거    
    file=open('bool.txt','r',encoding='UTF8')
    stopwords=file.readlines()[0].split(' ')
    file.close()
    
    temp_X = [word for word in temp_X if not word in stopwords] 
    tokenized_data.append(temp_X)
    return( ' '.join(temp_X) )

df['cleaned'] = df['info'].apply(_removeNonAscii)
df['cleaned'] = df['cleaned'].apply(remove_stop_words)

# %%
# 상위 5행만 출력하여 확인

# %%
df['cleaned'][:5]
# Out:
# 0    특 유의 냉소 캐릭터 독특 그림 체 데뷔 초기 예리 매니아 집단 형성 작가 예리 파...
# 1    서울 태어나다 경북 영양 밀양 부산 등지 자르다 서울대학교 사범대 학 수학 동아일보...
# 2    저자 조 애너 콜 어리다 과학 좋다 영리 소녀 신기 스쿨 버스 프리 즐 선생님 처럼...
# 3    서울 출생 서울대학교 산업 미술 학과 고려대 신문방송학 대학원 졸업 파리 대학 커뮤...
# 4    일본 도쿄 태어나다 광복 직후 우리나라 돌아오다 경북 안동 일직면 마을 교회 종 지...
# Name: cleaned, dtype: object

# %%
# 빈 값이 있는 행 확인, nan 값으로 변환 후 해당 행 제거

# %%
df['cleaned'].replace('', np.nan, inplace=True)
df = df[df['cleaned'].notna()]
print('전체 문서의 수 :', len(df))
# Out:
# 전체 문서의 수 : 417

# %%
# 토큰화하여 corpus 라는 리스트에 저장

# %%
corpus = []
for words in df['cleaned']:
    corpus.append(words.split())

# %% [markdown]
# 2. Word2Vec을 통해 이를 초기 단어 벡터값으로 워드 임베딩

# %%
model = Word2Vec(corpus, size = 300, window=5, min_count = 10, workers = -1)

# %%
word_vectors = model.wv
vocabs = word_vectors.vocab.keys()
word_vectors_list = [word_vectors[v] for v in vocabs]

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vectors_list)
xs = xys[:,0]
ys=xys[:,1]

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
fm._rebuild()

plt.rc('font', family='NanumGothic')

import matplotlib.pyplot as plt

def plot_2d_graph(vocabs, xs, ys):
    plt.figure(figsize=(20,20))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs):
        plt.annotate(v,xy=(xs[i], ys[i]))
        
plot_2d_graph(vocabs, xs,ys)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 3. 단어 벡터의 평균 구하기

# %%
word2vec_model=model
def vectors(document_list):
    document_embedding_list = []

    # 각 문서에 대해서
    for line in document_list:
        doc2vec = None
        count = 0
        for word in line.split():
            if word in word2vec_model.wv.vocab.keys():
                count += 1
                # 해당 문서에 있는 모든 단어들의 벡터값을 더한다.
                if doc2vec is None:
                    doc2vec = word2vec_model[word]
                else:
                    doc2vec = doc2vec + word2vec_model[word]

        if doc2vec is not None:
            # 단어 벡터를 모두 더한 벡터의 값을 문서 길이로 나눠준다.
            doc2vec = doc2vec / count
            document_embedding_list.append(doc2vec)

    # 각 문서에 대한 문서 벡터 리스트를 리턴
    return document_embedding_list

# %%
document_embedding_list = vectors(df['cleaned'])
print('문서 벡터의 수 :',len(document_embedding_list))
# Out:
# <ipython-input-17-ca7270387c53>:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = word2vec_model[word]
# <ipython-input-17-ca7270387c53>:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = doc2vec + word2vec_model[word]
# 문서 벡터의 수 : 417

# %% [markdown]
# 4. 추천 시스템 구현하기

# %%
# 각 벡터간 코사인 유사도

cosine_similarities = cosine_similarity(document_embedding_list, document_embedding_list)
print('코사인 유사도 매트릭스의 크기 :',cosine_similarities.shape)
# Out:
# 코사인 유사도 매트릭스의 크기 : (417, 417)

# %%
# 코사인 유사도를 이용하여, 가장 설명이 유사한 5개의 작가을 찾아내는 함수 만들기

# %%
def recommendations_by_author(author):
    books = df[['author']]
    # 작가를 입력하면 해당 작가의 인덱스를 리턴받아 idx에 저장.
    indices = pd.Series(df.index, index = df['author']).drop_duplicates() 
    idx = indices[author]

    # 입력된 작가과 작가설명(document embedding)가 유사한 책 5개 선정.
    sim_scores = list(enumerate(cosine_similarities[idx]))
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
    sim_scores = sim_scores[1:6]

    # 가장 유사한 작가의 인덱스
    book_indices = [i[0] for i in sim_scores]

    # 전체 데이터프레임에서 해당 인덱스의 행만 추출. 5개의 행을 가진다.
    recommend = books.iloc[book_indices].reset_index(drop=True)

    # 데이터프레임으로부터 순차적으로 작가를 출력
    for i in book_indices:
        print(books.loc[i]['author'])

# %%
# 확인 : 작가를 입력하면 소개가 유사한 작가들 추천

# %%
recommendations_by_author('파울로 코엘료')
# Out:
# J.K. 롤링
# 스티븐 킹
# 앙투안 드 생텍쥐페리
# 무라카미 하루키
# 앤서니 브라운

# %%
recommendations_by_author('J.K. 롤링')
# Out:
# 파울로 코엘료
# 시드니 셀던
# 스티븐 킹
# 루시 모드 몽고메리
# 박완서

# %%
recommendations_by_author('한강')
# Out:
# 임철우
# 로저 젤라즈니
# 최윤
# 조경란
# 공지영

# %%
recommendations_by_author('헤르만 헤세')
# Out:
# 레프 톨스토이
# 어네스트 밀러 헤밍웨이
# 박완서
# 이청준
# 신경숙

# %%
recommendations_by_author('무라카미 하루키')
# Out:
# 스티븐 킹
# 호르헤 루이스 보르헤스
# 파울로 코엘료
# 이승우
# 비벌리 클리어리

# %%
recommendations_by_author('스티븐 킹')
# Out:
# 로저 젤라즈니
# 무라카미 하루키
# 시드니 셀던
# 파울로 코엘료
# J.K. 롤링
