# %% [markdown]
# 문서 내 각 단어들을 Word2Vec을 통해 단어 벡터로 변환하고, 이들의 평균으로 문서 벡터를 구하여 선호하는 도서와 유사한 도서를 찾아주는 도서 추천 시스템 만들기
#
# 1. 데이터 로드

# %%
# 패키지 임포트

import urllib.request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import re
from konlpy.tag import Okt
from io import BytesIO
# !pip install gensim==3.7.0 --user
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Requirement already satisfied: gensim==3.7.0 in c:\users\user\appdata\roaming\python\python38\site-packages (3.7.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\user\anaconda3\lib\site-packages (from gensim==3.7.0) (1.6.2)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\user\anaconda3\lib\site-packages (from gensim==3.7.0) (1.20.0)
# Requirement already satisfied: smart-open>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from gensim==3.7.0) (1.9.0)
# Requirement already satisfied: six>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from gensim==3.7.0) (1.15.0)
# Requirement already satisfied: boto3 in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.7.0->gensim==3.7.0) (1.17.88)
# Requirement already satisfied: bz2file in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.7.0->gensim==3.7.0) (0.98)
# Requirement already satisfied: boto>=2.32 in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.7.0->gensim==3.7.0) (2.49.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.7.0->gensim==3.7.0) (2.26.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.7.0->gensim==3.7.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.7.0->gensim==3.7.0) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.88 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.7.0->gensim==3.7.0) (1.20.94)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\user\anaconda3\lib\site-packages (from botocore<1.21.0,>=1.20.88->boto3->smart-open>=1.7.0->gensim==3.7.0) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\user\anaconda3\lib\site-packages (from botocore<1.21.0,>=1.20.88->boto3->smart-open>=1.7.0->gensim==3.7.0) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->smart-open>=1.7.0->gensim==3.7.0) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests->smart-open>=1.7.0->gensim==3.7.0) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->smart-open>=1.7.0->gensim==3.7.0) (2.6)

# %%
# 데이터를 데이터프레임으로 로드하고, 전체 문서의 수 출력

# %%
import io

df = pd.read_csv('bookdata.csv')
print('전체 문서의 수 : ', len(df))
# Out:
# 전체 문서의 수 :  61

# %%
# 상위 5행만 출력하여 확인

# %%
df[:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1           isbn  \
# 0           0             1  9788935668663
# 1           1             2  9791191056556
# 2           2             3  9791167370280
# 3           3             4  9791190977265
# 4           4             5  9791191347180
#
#                                               review  \
# 0  이책을 접하지못했다 나도 언론에서 내보이는 헤드라인으로 세상을 입력했을지도 모른다....
# 1  주변에서 평이 좋아서 구매하게 된 책.\n괜히 입소문을 탄 게 아니다 싶은게 원래 ...
# 2  제목: 완전한 행복\n글쓴이: 정유정\n펴낸 곳: 은행나무\n       오래도록 ...
# 3  책 제목  \n - 부의 시나리오\n  나의 상황 \n  - 부자 되고 싶습니다. ...
# 4  이 책은 트레이딩에 관한 기술적 분석을 알려준다.\n\n다른 책과의 차별성은 추세선...
#
#                                              cleaned       title  \
# 0  이책을 접하지못했다 나도 언론에서 내보이는 헤드라인으로 세상을 입력했을지도 모른다 ...      조국의 시간
# 1  주변에서 평이 좋아서 구매하게 된 책  괜히 입소문을 탄 게 아니다 싶은게 원래 종...  미드나잇 라이브러리
# 2  제목  완전한 행복 글쓴이  정유정 펴낸 곳  은행나무        오래도록 기다린...      완전한 행복
# 3  책 제목      부의 시나리오   나의 상황      부자 되고 싶습니다     ...     부의 시나리오
# 4  이 책은 트레이딩에 관한 기술적 분석을 알려준다   다른 책과의 차별성은 추세선과 ...      매매의 기술
#
#                                             contents  \
# 0  『조국의 시간』은 2019년 8월 9일, 조국이 법무부장관 후보로 지명된 이후 벌어...
# 1  ★ 영국 아마존 종합 베스트셀러 1위 ★ 미국 아마존, 《뉴욕타임스》, 《선데이타임...
# 2  《내 인생의 스프링 캠프》 《내 심장을 쏴라》 《7년의 밤》 《28》 《종의 기원》...
# 3  오건영 저자가 불안한 금융시장 속, 흔들리는 투자자들의 다음 스텝을 지켜주기 위해 ...
# 4  매매를 하다 보면 매 순간 선택의 갈림길에 놓인다. 이유는 모르지만 갑자기 매수세가...
#
#                                            thumbnail authors
# 0  https://search1.kakaocdn.net/thumb/R120x174.q8...      조국
# 1  https://search1.kakaocdn.net/thumb/R120x174.q8...  매트 헤이그
# 2  https://search1.kakaocdn.net/thumb/R120x174.q8...     정유정
# 3  https://search1.kakaocdn.net/thumb/R120x174.q8...     오건영
# 4  https://search1.kakaocdn.net/thumb/R120x174.q8...     박병창

# %%
# 형태소 분석 하기 전 사용자 사전 추가
from ckonlpy.tag import Twitter
twitter = Twitter()
twitter.add_dictionary(list(df['authors']),'Noun')
# Out:
# C:\Users\user\AppData\Roaming\Python\Python38\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
# 'Desc' 열을 대상으로 전처리를 수행하여 'cleaned'에 저장

# %%
def _removeNonAscii(text):
    letters_only = re.sub('[^0-9가-힣]', '', text)   
    return letters_only

def remove_stop_words(text):
    twitter = Twitter()
    tokenized_data = []
    temp_X = twitter.nouns(text) # 토큰화
    
    # 5. Stopwords 불용어 제거    
    file=open('bool.txt','r',encoding='UTF8')
    stopwords=file.readlines()[0].split(' ')
    file.close()
    
    temp_X = [word for word in temp_X if not word in stopwords] 
    tokenized_data.append(temp_X)
    return( ' '.join(temp_X) )

#df['cleaned'] = df['review'].apply(_removeNonAscii)
df['cleaned'] = df.cleaned.apply(remove_stop_words)

# %%
# 상위 5행만 출력하여 확인

# %%
df['cleaned'][:5]
# Out:
# 0    책 접 언론 헤드라인 세상 입력 을지 유투브 영상 접 전달 체 왜곡 그대로 수하 진...
# 1    주변 평이 매하 책 입 소문 원래 종이 책 오래 못 나인 퇴근 부지런 이틀 기대 책...
# 2    제목 행복 글 정유 정 곳 은행나무 오래 도록 다린 정유 정 작가 신간 완벽 글 완...
# 3    책 제목 부의 시나리오 상황 부자 금융 공부 필요 시점 줄거리 요약 불 확실성 기회...
# 4    책 트 레이 딩 관 기술 분석 책 차별성 추세 선 지지 선 저항 선의 자주 개념 언...
# Name: cleaned, dtype: object

# %%
# 빈 값이 있는 행 확인, nan 값으로 변환 후 해당 행 제거

# %%
df['cleaned'].replace('', np.nan, inplace=True)
df = df[df['cleaned'].notna()]
print('전체 문서의 수 :', len(df))
# Out:
# 전체 문서의 수 : 61

# %%
# 토큰화하여 corpus 라는 리스트에 저장

# %%
corpus = []
for words in df['cleaned']:
    corpus.append(words.split())

# %% [markdown]
# 2. Word2Vec을 통해 이를 초기 단어 벡터값으로 워드 임베딩

# %%
model = Word2Vec(corpus, size = 300, window=5, min_count = 5, workers = -1)
#word2vec_model.intersect_word2vec_format('GoogleNews-vectors-negative300.bin.gz', lockf=1.0, binary=True)
#word2vec_model.train(corpus, total_examples = word2vec_model.corpus_count, epochs = 15)

# %% [markdown]
# 3. 단어 벡터의 평균 구하기

# %%
word2vec_model=model

def vectors(document_list):
    document_embedding_list = []

    # 각 문서에 대해서
    for line in document_list:
        doc2vec = None
        count = 0
        for word in line.split():
            if word in word2vec_model.wv.vocab.keys():
                count += 1
                # 해당 문서에 있는 모든 단어들의 벡터값을 더한다.
                if doc2vec is None:
                    doc2vec = word2vec_model[word]
                else:
                    doc2vec = doc2vec + word2vec_model[word]

        if doc2vec is not None:
            # 단어 벡터를 모두 더한 벡터의 값을 문서 길이로 나눠준다.
            doc2vec = doc2vec / count
            document_embedding_list.append(doc2vec)

    # 각 문서에 대한 문서 벡터 리스트를 리턴
    return document_embedding_list 

document_embedding_list = vectors(df['cleaned'])
print('문서 벡터의 수 :',len(document_embedding_list))
# Out:
# <ipython-input-16-6bc9cd06868f>:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = word2vec_model[word]
# <ipython-input-16-6bc9cd06868f>:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   doc2vec = doc2vec + word2vec_model[word]
# 문서 벡터의 수 : 61

# %%
def keyword_vector(keyword_list):
    
    # 각 키워드에 대해서
    key2vec = None
    count = 0
    
    for word in keyword_list:
        if word in word2vec_model.wv.vocab.keys():
                count += 1
                # 해당 문서에 있는 모든 단어들의 벡터값을 더한다.
                if key2vec is None:
                    key2vec = word2vec_model[word]
                else:
                    key2vec = key2vec + word2vec_model[word]

    if key2vec is not None:
            # 단어 벡터를 모두 더한 벡터의 값을 키워드 개수로 나눠준다.
        key2vec = key2vec / count
            
    # 각 문서에 대한 문서 벡터 리스트를 리턴
    return key2vec

# %% [markdown]
# 4. 추천 시스템 구현하기

# %%
# 코사인 유사도를 이용하여, 가장 줄거리가 유사한 5개의 책을 찾아내는 함수 만들기

# %%
from sklearn.preprocessing import MinMaxScaler
from numpy import dot
from numpy.linalg import norm

def cos_sim(A, B):
       return dot(A, B)/(norm(A)*norm(B))


def recommendation_by_keyword(keyword_list):
    
    keyVector=keyword_vector(keyword_list)
    
    books = df[['title']]
    
    cosine_similarities2=[]
    for doc in document_embedding_list:
        cosine_similarities2.append(cos_sim(keyVector, np.array(doc)))
    

    # 입력된 책과 줄거리(document embedding)가 유사한 책 5개 선정.
    sim_scores = list(enumerate(cosine_similarities2))
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
    sim_scores = sim_scores[1:6]

    # 가장 유사한 책 5권의 인덱스
    book_indices = [i[0] for i in sim_scores]

    # 전체 데이터프레임에서 해당 인덱스의 행만 추출. 5개의 행을 가진다.
    recommend = books.iloc[book_indices].reset_index(drop=True)

    # 데이터프레임으로부터 순차적으로 이미지를 출력
    for i in book_indices:
        print(books.loc[i]['title'])

# %%
print(word2vec_model.wv.vocab.keys())
# Out:
# dict_keys(['책', '접', '언론', '세상', '입력', '을지', '유투브', '영상', '전달', '체', '왜곡', '그대로', '수하', '진실', '공부', '는걸', '정치', '뉴스', '티비', '보고', '고서', '판단', '문외한', '통해', '삶', '요즘', '경제', '주식', '비트코인', '관련', '상당', '중요', '다가', '나름', '충격', '고도', '어깨', '표현', '분', '요', '정말', '목숨', '온', '국민', '난', '고통', '힘', '시민', '응원', '나니', '계속', '신뢰', '메시지', '듭니', '솔직', '끝', '지지', '마음', '아주', '시기', '가족', '감사', '안함', '전하', '어요', '건강', '계', '조국', '꼭', '걸', '한번', '소름', '수가', '끼', '의식', '무리', '웃음', '더러', '운', '글', '거리', '진짜', '감히', '갈수록', '지인', '선물', '하니', '무게', '무거', '눈물', '문장', '내기', '리도', '심정', '댁', '용기', '내시', '어도', '오지', '죄', '아내', '땅', '나라', '무지', '걸음', '변화', '음', '합', '다정', '인간', '속성', '시대', '근본', '형', '성하', '해', '보호', '고자', '적용', '제도', '나은', '만들기', '위해', '뜻', '이하', '나로', '문명', '화', '인문', '주의', '꽃', '래서', '존경', '거짓', '의지', '대가', '정권', '자리', '약자', '아가', '목표', '자살', '거', '돈', '사기', '서점', '희망', '분노', '결론', '금', '변명', '판', '리', '뇌', '판타지', '문학', '태양', '빛', '주변', '매하', '입', '소문', '원래', '종이', '오래', '못', '부지런', '이틀', '기대', '런가', '흥미진진', '요소', '부족', '주제', '선택', '후회', '루고', '다양', '결과', '매체', '간접', '경험', '꽤', '만족', '고', '광고', '땐', '영화', '던데', '얼른', '죽음', '사이', '이야기', '볼', '제이다', '여러', '아보', '기도', '상상', '미국', '인생', '극장', '분위기', '스토리', '전개', '었다', '방향', '대부분', '예상', '었', '부분', '전혀', '뜻밖', '거나', '뭐', '핵심', '인지도', '주인공', '가장', '동화', '순간', '역시', '소설', '달러', '구트', '꿈', '백화점', '연관', '그거', '인적', '좀더', '자체', '재미', '덕', '베스트셀러', '수도', '반대', '실망', '듯', '선', '역', '도서관', '기회', '완벽', '여정', '시작', '어가', '타고', '과거', '미래', '는가', '가정', '아직', '현실', '이루', '가능성', '일일', '어쩌면', '지도', '더라면', '지고', '나중', '자책', '설정', '상적', '생', '각하', '어진', '아들', '질문', '고민', '답', '모든', '권', '았', '자정', '마법', '하자', '결심', '사랑', '어머니', '직장', '일어', '날', '심각', '우울', '절망', '감', '곁', '아무', '신경', '외로움', '고독', '이제', '필요', '우주', '불', '존재', '사라', '블랙홀', '근처', '가면', '법', '전의', '사서', '엘름', '만남', '스물', '라가', '과정', '만난', '에피소드', '여준', '학교', '부인', '전해', '준', '의사', '친구', '이기', '옆집', '인물', '가의', '관계', '여주', '인연', '차', '지하', '댓글', '새', '요청', '연민', '맞이', '기억', '깨달', '적합', '실수', '었으', '매일', '모습', '도착', '곳', '사방', '초록색', '건물', '보이지', '온갖', '선명', '색', '나머지', '여름', '가가', '거기', '그냥', '비밀', '달라', '회하', '중간', '지대', '친절', '안내', '뼈', '기록', '군', '헤어', '시골', '책장', '결혼', '직전', '움직', '야만', '막상', '영하', '족하', '행복', '남', '뿐', '런', '거울', '행운', '어딘가', '호기심', '미소', '바', '라보', '주인', '방식', '선수', '평범', '지루', '진정', '자꾸만', '원한', '인지', '멀리', '소', '중하', '며', '정착', '이란', '자세', '불완전', '처럼', '여지', '작품', '현재', '듯이', '지우', '분명', '다시금', '내용', '완', '노력', '탄생', '주어', '잡', '결코', '기술', '정신', '리뷰', '클럽', '서평', '자격', '작성', '최선', '우린', '책임', '지속', '궁금', '해지', '제목', '정유', '정', '은행나무', '도록', '작가', '신간', '질', '손', '치밀', '가슴', '열', '사하', '유일', '마주', '설', '정이', '자기애', '늪', '울', '빠', '지게', '유나', '시점', '딸', '지유', '언니', '재인', '남편', '호', '시선', '교', '향', '간다', '덧셈', '뺄셈', '보통', '돌이', '장애물', '그게', '제거', '도달', '스라이', '팅', '죄책감', '이용', '짓', '저지', '르', '배', '신하', '초반', '자꾸', '누군가', '틀', '리지', '실제', '지면', '밖', '시공간', '배경', '서사', '직접', '언급', '사건', '처음', '살이', '며칠', '범죄', '심리', '노트', '범죄자', '성격장애', '가차', '살해', '지나', '리라', '개인', '유', '일무', '존중', '특별', '인정', '길', '대우', '격려', '공동체', '단어', '홀로', '권리', '장하', '대체', '잡고', '관', '본적', '배려', '욕망', '부작', '화려', '문', '완성', '가치', '하든', '출판사', '서포터즈', '도서', '지원', '입하', '니야', '체적', '얘기', '전해질', '불행', '표지', '눈', '코', '오리', '마리', '뭔가', '부', '첫', '페이지', '안정', '연상', '위험', '추구', '위', '간', '상대', '물이', '조화', '더욱', '수록', '손가락', '절대', '에릭', '소크라테스', '익스', '프레', '스', '나르시시스트', '협찬', '추천', '건', '한국', '근대', '한동', '해주', '종종', '일본', '악', '근원', '쉬', '매력', '탈', '심장', '밤', '최근', '초기', '치면', '세계', '발', '그린', '풍경', '잔', '국가', '재난', '사태', '교하', '묘사', '속도', '굳이', '이유', '동시', '습관', '외국', '건너', '신작', '본성', '명확', '로만', '재혼', '번갈아', '각기', '호의', '성취', '열차', '새벽', '시', '부서', '살짝', '이기심', '파괴', '터', '오랜만', '도장', '깨', '기하', '영원', '명제', '출발', '예전', '문하', '대답', '머릿속', '때론', '정성', '다해', '결말', '마지막', '먹이', '보시', '느낌', '명의', '등장인물', '하루하루', '두려움', '상황', '정확', '감정', '휘', '의문', '모티브', '상태', '앞길', '대상', '원인', '성', '경계', '구석', '사이코패스', '니지', '어보', '남자', '아버지', '이슈', '짐작', '자존감', '강박증', '고유' ...

# %%
# 확인 : 책 제목을 입력하면 이와 유사한 책들 추천(제목, 표지)

# %%
recommendation_by_keyword(['주식','유용','투자'])
# Out:
# 주식투자 무작정 따라하기
# 주린이가 가장 알고 싶은 최다질문 TOP 77
# 부의 인문학
# 매매의 기술
# 부의 시나리오
# <ipython-input-17-f8cf6950d332>:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   key2vec = word2vec_model[word]
# <ipython-input-17-f8cf6950d332>:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   key2vec = key2vec + word2vec_model[word]

# %%
recommendation_by_keyword(['삶','죽음','인문'])
# Out:
# 미드나잇 라이브러리
# 떠난 후에 남겨진 것들
# 파친코. 1
# 소크라테스 익스프레스
# 푸른 사자 와니니
# <ipython-input-17-f8cf6950d332>:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   key2vec = word2vec_model[word]
# <ipython-input-17-f8cf6950d332>:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   key2vec = key2vec + word2vec_model[word]

# %%
recommendation_by_keyword(['꿈','고독'])
